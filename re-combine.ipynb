# %%
import pandas as pd
answer14 = pd.read_csv('answer14.csv',header = -1)

# %%
a14 = [9 for i in range(len(answer14))]
b14 = [9 for i in range(len(answer14))]
c14 = [9 for i in range(len(answer14))]
j=0
for i in answer14[0]:
    a14[j],b14[j],c14[j]=i.split("_")
    j=j+1

# %%
df_answera = pd.read_csv("predict_task_A_8.csv")
answera = df_answera["0"]

# %% [markdown]
# answera和b14

# %%
b_last_three = [9 for i in range(len(answer14))]
for i in range(len(answer14)):
    b_last_three[i] = b14[i][1:]

# %%
df_b_first = pd.read_csv("predict_task_B_1.csv")
b_first = df_b_first["0"]

# %%
answerb = [9 for i in range(len(answer14))]
i = 0
for i in range(len(answer14)):
    answerb[i] = str(int(b_first[i]))+ str(b_last_three[i])

# %%
c_first = [9 for i in range(len(answer14))]
c_second = [9 for i in range(len(answer14))]
c_third = [9 for i in range(len(answer14))]
c_forth = [9 for i in range(len(answer14))]
i = 0
for i in range(len(answer14)):
    c_first[i] = c14[i][0]
    c_second[i] = c14[i][1]
    c_third[i] = c14[i][2]
    c_forth[i] = c14[i][3]

# %%
df_answer_c2 = pd.read_csv("predict_task_C_2.csv")
answer_c2 = df_answer_c2["0"]

# %%
df_answer_c3 = pd.read_csv("predict_task_C_3.csv")
answer_c3 = df_answer_c3["0"]

# %%
answerc = [9 for i in range(len(answer14))]
i = 0
for i in range(len(answer14)):
    answerc[i] = str(c_first[i])+ str(answer_c2[i])+str(answer_c3[i])+str(c_forth[i])

# %%
res = [9 for i in range(len(answer14))]
for i in range(len(res)):
    res[i] = str(a14[i])+"_"+b14[i]+"_"+answerc[i]

# %%
pd.DataFrame(res).to_csv("result.csv",header = None,index = None)

# %%
av2=pd.read_csv("predict_task_A_2.csv")

# %%
import pandas as pd
answer1 = pd.read_csv('answer1.csv',header = -1)

# %%
answera = pd.read_csv('predict_task_A_4.csv')
answerb1 = pd.read_csv('predict_task_B_1.csv')
answerb3 = pd.read_csv('predict_task_B_3.csv')
answerc1 = pd.read_csv('predict_task_C_1.csv')

# %%
a1 = [9 for i in range(len(answer1))]
b1 = [9 for i in range(len(answer1))]
c1 = [9 for i in range(len(answer1))]
j=0
for i in answer1[0]:
    a1[j],b1[j],c1[j]=i.split("_")
    j=j+1

# %%
b1
# Out:
# ['1110',
#  '1011',
#  '1110',
#  '1111',
#  '1010',
#  '1010',
#  '1011',
#  '1011',
#  '1101',
#  '0111',
#  '1011',
#  '1111',
#  '1111',
#  '1101',
#  '1110',
#  '1110',
#  '1010',
#  '1101',
#  '1010',
#  '1110',
#  '1111',
#  '1101',
#  '1011',
#  '1011',
#  '1111',
#  '1111',
#  '0111',
#  '1101',
#  '1110',
#  '1110',
#  '1111',
#  '1101',
#  '1011',
#  '1101',
#  '1111',
#  '1111',
#  '1001',
#  '1110',
#  '1110',
#  '1010',
#  '1010',
#  '1001',
#  '1010',
#  '1011',
#  '1011',
#  '1110',
#  '1011',
#  '1110',
#  '1011',
#  '1011',
#  '1110',
#  '1110',
#  '1001',
#  '1101',
#  '0111',
#  '1111',
#  '1110',
#  '1001',
#  '1110',
#  '1111',
#  '1111',
#  '1110',
#  '1010',
#  '1111',
#  '1110',
#  '1111',
#  '1101',
#  '1111',
#  '1100',
#  '1010',
#  '0110',
#  '1000',
#  '1010',
#  '1111',
#  '1111',
#  '1111',
#  '1110',
#  '1111',
#  '1111',
#  '1111',
#  '1011',
#  '1000',
#  '1111',
#  '1111',
#  '1100',
#  '1111',
#  '1101',
#  '1100',
#  '1111',
#  '1110',
# ...

# %%
b_last_three = [9 for i in range(len(answer1))]
for i in range(len(answer1)):
    b_last_three[i] = b1[i][1:]

# %%
final_b = [9 for i in range(len(answer1))]
for i in range(len(answer1)):
    final_b[i] = str(int(answerb1["0"][i]))+str(b_last_three[i])

# %%
c_last_three = [9 for i in range(len(answer1))]
for i in range(len(answer1)):
    c_last_three[i] = c1[i][1:]

# %%
final_c = [9 for i in range(len(answer1))]
for i in range(len(answer1)):
    final_c[i] = str(int(answerc1["0"][i]))+str(c_last_three[i])

# %%
def outside_task(a,b,c):
    return str(a)+"_"+b+"_"+c

# %%
total = [9 for i in range(len(answer1))]
for j in range(len(answer1)):
    total[j] = outside_task(answera['0'][j],final_b[j],final_c[j])

# %%
total
# Out:
# ['1_1110_1110',
#  '1_0011_2011',
#  '1_1110_2110',
#  '1_1111_2311',
#  '1_1010_1100',
#  '1_1010_2010',
#  '1_1011_1011',
#  '1_1011_3311',
#  '1_1101_0111',
#  '1_1111_0311',
#  '1_1011_2121',
#  '1_1111_0011',
#  '1_1111_2011',
#  '1_1101_2011',
#  '1_1110_2010',
#  '1_1110_1120',
#  '1_1010_1120',
#  '1_1101_1101',
#  '1_1010_1010',
#  '1_0110_2020',
#  '1_1111_1111',
#  '1_1101_1311',
#  '1_1011_1131',
#  '1_0011_1011',
#  '1_1111_1131',
#  '1_1111_2011',
#  '1_1111_2311',
#  '1_1101_1111',
#  '1_1110_1010',
#  '1_1110_1120',
#  '1_1111_1121',
#  '1_1101_1111',
#  '1_1011_1121',
#  '1_1101_2111',
#  '1_1111_1031',
#  '1_1111_2001',
#  '1_1001_2111',
#  '1_0110_3020',
#  '1_1110_1110',
#  '1_1010_0310',
#  '1_0010_2020',
#  '1_1001_1011',
#  '1_0010_1310',
#  '1_1011_0011',
#  '1_1011_2101',
#  '1_0110_0010',
#  '1_0011_1021',
#  '1_1110_2310',
#  '1_0011_1011',
#  '1_1011_2131',
#  '1_1110_2110',
#  '1_1110_2130',
#  '1_1001_1311',
#  '1_1101_2121',
#  '1_1111_3311',
# ...

# %%
pd.DataFrame(total).to_csv('answer.csv',header = None,index = None)

# %%
answer11 = pd.read_csv('answer11.csv',header = -1)
a11 = [9 for i in range(len(answer11))]
b11 = [9 for i in range(len(answer11))]
c11 = [9 for i in range(len(answer11))]
j=0
for i in answer11[0]:
    a11[j],b11[j],c11[j]=i.split("_")
    j=j+1

# %%
b11_second = [9 for i in range(len(answer11))]
for i in range(len(answer11)):
    b11_second[i] = b11[i][1]

# %%
b11_forth = [9 for i in range(len(answer11))]
for i in range(len(answer11)):
    b11_forth[i] = b11[i][3]

# %%
final_b = [9 for i in range(len(answer11))]
for i in range(len(answer11)):
    final_b[i] = str(int(answerb1["0"][i]))+str(b11_second[i])+str(int(answerb3["0"][i]))+str(b11_forth[i])

# %%
final_b
# Out:
# ['1110',
#  '0001',
#  '1110',
#  '1111',
#  '1010',
#  '1010',
#  '1011',
#  '1011',
#  '1111',
#  '1111',
#  '1011',
#  '1111',
#  '1101',
#  '1111',
#  '1100',
#  '1110',
#  '1000',
#  '1101',
#  '1000',
#  '0110',
#  '1111',
#  '1111',
#  '1011',
#  '0011',
#  '1111',
#  '1111',
#  '1111',
#  '1101',
#  '1110',
#  '1110',
#  '1111',
#  '1111',
#  '1001',
#  '1111',
#  '1111',
#  '1111',
#  '1001',
#  '0110',
#  '1110',
#  '1010',
#  '0000',
#  '1001',
#  '0000',
#  '1011',
#  '1001',
#  '0110',
#  '0011',
#  '1110',
#  '0011',
#  '1011',
#  '1110',
#  '1110',
#  '1011',
#  '1111',
#  '1111',
#  '0101',
#  '1100',
#  '1001',
#  '1100',
#  '1111',
#  '0111',
#  '1110',
#  '1000',
#  '1111',
#  '1110',
#  '1101',
#  '1111',
#  '0111',
#  '1100',
#  '1000',
#  '1100',
#  '0010',
#  '1010',
#  '1111',
#  '1101',
#  '1101',
#  '1110',
#  '1101',
#  '1111',
#  '1111',
#  '1011',
#  '0010',
#  '0101',
#  '1111',
#  '1110',
#  '0111',
#  '1101',
#  '1110',
#  '1101',
#  '1100',
# ...

# %%
total = [9 for i in range(len(answer1))]
for j in range(len(answer1)):
    total[j] = outside_task(a11[j],b11[j],final_c[j])

# %%
len(total)
# Out:
# 1878

# %% [markdown]
# # 替换taskA

# %%
import pandas as pd
answer20 = pd.read_csv('answer237.csv',header = -1)

# %%
a20 = [9 for i in range(len(answer20))]
b20 = [9 for i in range(len(answer20))]
c20 = [9 for i in range(len(answer20))]
j=0
for i in answer20[0]:
    a20[j],b20[j],c20[j]=i.split("_")
    j=j+1

# %%
df_answera = pd.read_csv("predict_task_A.csv")

# %%
answera = df_answera["0"]

# %%
total = [9 for i in range(len(answer20))]
for j in range(len(answer20)):
    total[j] = outside_task(answera[j],b20[j],c20[j])

# %%
pd.DataFrame(total).to_csv('answer.csv',header = None,index = None)

# %% [markdown]
# # 替换taskB_1

# %%
import pandas as pd
#answerb1 = pd.read_csv('predict_task_B_1.csv')
answer20 = pd.read_csv('answer237.csv',header = -1)

# %%
a20 = [9 for i in range(len(answer20))]
b20 = [9 for i in range(len(answer20))]
c20 = [9 for i in range(len(answer20))]
j=0
for i in answer20[0]:
    a20[j],b20[j],c20[j]=i.split("_")
    j=j+1

# %%
b_last_three = [9 for i in range(len(answer20))]
for i in range(len(answer20)):
    b_last_three[i] = b20[i][1:]

# %%
df_b_first = pd.read_csv("predict_task_B_1.csv")
b_first = df_b_first["0"]

# %%
answerb = [9 for i in range(len(answer20))]
i = 0
for i in range(len(answer20)):
    answerb[i] = str(int(b_first[i]))+ str(b_last_three[i])

# %%
res = [9 for i in range(len(answer20))]
for i in range(len(res)):
    res[i] = str(a20[i])+"_"+answerb[i]+"_"+str(c20[i])

# %%
pd.DataFrame(res).to_csv("result.csv",header = None,index = None)

# %% [markdown]
# # 替换taskB_3

# %%
import pandas as pd
answerb3 = pd.read_csv('predict_task_B_3.csv')
answer20 = pd.read_csv('answer235.csv',header = -1)

# %%
a20 = [9 for i in range(len(answer20))]
b20 = [9 for i in range(len(answer20))]
c20 = [9 for i in range(len(answer20))]
j=0
for i in answer20[0]:
    a20[j],b20[j],c20[j]=i.split("_")
    j=j+1

# %%
b20_first_second = [9 for i in range(len(answer20))]
for i in range(len(answer20)):
    b20_first_second[i] = b20[i][0:2]

# %%
b20[0][0:3]
# Out:
# '111'

# %%
b20_forth = [9 for i in range(len(answer20))]
for i in range(len(answer20)):
    b20_forth[i] = b20[i][3]

# %%
final_b = [9 for i in range(len(answer20))]
for i in range(len(answer20)):
    final_b[i] = str(b20_first_second[i])+str(int(answerb3["0"][i]))+str(b20_forth[i])

# %%
res = [9 for i in range(len(answer20))]
for i in range(len(res)):
    res[i] = str(a20[i])+"_"+final_b[i]+"_"+str(c20[i])

# %% [markdown]
# # 替换taskB_2

# %%
import pandas as pd
answerb2 = pd.read_csv('predict_task_B_2.csv')
answer20 = pd.read_csv('answer234.csv',header = -1)

# %%
a20 = [9 for i in range(len(answer20))]
b20 = [9 for i in range(len(answer20))]
c20 = [9 for i in range(len(answer20))]
j=0
for i in answer20[0]:
    a20[j],b20[j],c20[j]=i.split("_")
    j=j+1

# %%
b20_first = [9 for i in range(len(answer20))]
for i in range(len(answer20)):
    b20_first[i] = b20[i][0:1]

# %%
b20_third_forth = [9 for i in range(len(answer20))]
for i in range(len(answer20)):
    b20_third_forth[i] = b20[i][2:4]

# %%
final_b = [9 for i in range(len(answer20))]
for i in range(len(answer20)):
    final_b[i] = str(b20_first[i])+str(int(answerb2["0"][i]))+str(b20_third_forth[i])

# %%
res = [9 for i in range(len(answer20))]
for i in range(len(res)):
    res[i] = str(a20[i])+"_"+final_b[i]+"_"+str(c20[i])

# %%
pd.DataFrame(res).to_csv("result.csv",header = None,index = None)

# %%
替换了b2之后准确率高了

# %% [markdown]
# # 替换taskB_4

# %%
import pandas as pd
answerb4 = pd.read_csv('predict_task_B_4.csv')
answer219 = pd.read_csv('answer249.csv',header = -1)

# %%
a219 = [9 for i in range(len(answer219))]
b219 = [9 for i in range(len(answer219))]
c219 = [9 for i in range(len(answer219))]
j=0
for i in answer219[0]:
    a219[j],b219[j],c219[j]=i.split("_")
    j=j+1

# %%
b219_first_second_third = [9 for i in range(len(answer219))]
for i in range(len(answer219)):
    b219_first_second_third[i] = b219[i][0:3]

# %%
final_b = [9 for i in range(len(answer219))]
for i in range(len(answer219)):
    final_b[i] = str(b219_first_second_third[i])+str(int(answerb4["0"][i]))

# %%
res = [9 for i in range(len(answer219))]
for i in range(len(answer219)):
    res[i] = str(a219[i])+"_"+final_b[i]+"_"+str(c219[i])

# %%
pd.DataFrame(res).to_csv("result.csv",header = None,index = None)

# %% [markdown]
# # 替换taskC_1

# %%
import pandas as pd
answerc1 = pd.read_csv('predict_task_C_1.csv')
answer219 = pd.read_csv('answer249.csv',header = -1)

# %%
a219 = [9 for i in range(len(answer219))]
b219 = [9 for i in range(len(answer219))]
c219 = [9 for i in range(len(answer219))]
j=0
for i in answer219[0]:
    a219[j],b219[j],c219[j]=i.split("_")
    j=j+1

# %%
c219_second_third_forth = [9 for i in range(len(answer219))]
for i in range(len(answer219)):
    c219_second_third_forth[i] = c219[i][1:4]

# %%
final_c = [9 for i in range(len(answer219))]
for i in range(len(answer219)):
    final_c[i] = str(int(answerc1["0"][i]))+str(c219_second_third_forth[i])

# %%
res = [9 for i in range(len(answer219))]
for i in range(len(answer219)):
    res[i] = str(a219[i])+"_"+str(b219[i])+"_"+final_c[i]

# %% [markdown]
# # 替换taskC_2

# %%
import pandas as pd
answerc2 = pd.read_csv('predict_task_C_2.csv')
answer219 = pd.read_csv('answer237.csv',header = -1)

# %%
a219 = [9 for i in range(len(answer219))]
b219 = [9 for i in range(len(answer219))]
c219 = [9 for i in range(len(answer219))]
j=0
for i in answer219[0]:
    a219[j],b219[j],c219[j]=i.split("_")
    j=j+1

# %%
c219_first = [9 for i in range(len(answer219))]
for i in range(len(answer219)):
    c219_first[i] = c219[i][0]

# %%
c219_third_forth = [9 for i in range(len(answer219))]
for i in range(len(answer219)):
    c219_third_forth[i] = c219[i][2:4]

# %%
final_c = [9 for i in range(len(answer219))]
for i in range(len(answer219)):
    final_c[i] = str(c219_first[i])+str(int(answerc2["0"][i]))+str(c219_third_forth[i])

# %%
res = [9 for i in range(len(answer219))]
for i in range(len(answer219)):
    res[i] = str(a219[i])+"_"+str(b219[i])+"_"+final_c[i]

# %% [markdown]
# # 替换taskC_3

# %%
import pandas as pd
answerc3 = pd.read_csv('predict_task_C_3.csv')
answer219 = pd.read_csv('answer237.csv',header = -1)

# %%
a219 = [9 for i in range(len(answer219))]
b219 = [9 for i in range(len(answer219))]
c219 = [9 for i in range(len(answer219))]
j=0
for i in answer219[0]:
    a219[j],b219[j],c219[j]=i.split("_")
    j=j+1

# %%
c219_first_second = [9 for i in range(len(answer219))]
for i in range(len(answer219)):
    c219_first_second[i] = c219[i][0:2]

# %%
c219_forth = [9 for i in range(len(answer219))]
for i in range(len(answer219)):
    c219_forth[i] = c219[i][3]

# %%
final_c = [9 for i in range(len(answer219))]
for i in range(len(answer219)):
    final_c[i] = str(c219_first_second[i])+str(int(answerc3["0"][i]))+str(c219_forth[i])

# %%
res = [9 for i in range(len(answer219))]
for i in range(len(answer219)):
    res[i] = str(a219[i])+"_"+str(b219[i])+"_"+final_c[i]

# %%
pd.DataFrame(res).to_csv("result.csv",header = None,index = None)

# %% [markdown]
# # 替换taskC_4

# %%
import pandas as pd
answerc4 = pd.read_csv('predict_task_B_4.csv')
answer219 = pd.read_csv('answer249.csv',header = -1)

# %%
a219 = [9 for i in range(len(answer219))]
b219 = [9 for i in range(len(answer219))]
c219 = [9 for i in range(len(answer219))]
j=0
for i in answer219[0]:
    a219[j],b219[j],c219[j]=i.split("_")
    j=j+1

# %%
c219_first_second_third = [9 for i in range(len(answer219))]
for i in range(len(answer219)):
    c219_first_second_third[i] = c219[i][0:3]

# %%
final_c = [9 for i in range(len(answer219))]
for i in range(len(answer219)):
    final_c[i] = str(c219_first_second_third[i])+str(int(answerc4["0"][i]))

# %%
res = [9 for i in range(len(answer219))]
for i in range(len(answer219)):
    res[i] = str(a219[i])+"_"+str(b219[i])+"_"+final_c[i]

# %%
更换阈值

# %%
import numpy as np
predicts = np.array(pd.read_csv("predict_task_B_2_v1.csv"))
i = 0
while i < len(predicts):
    if predicts[i]>0.7:
        predicts[i] = 1
    else:
        predicts[i] = 0
    i = i+1
pd.DataFrame(predicts).to_csv("predict_task_B_2.csv",index=False)
